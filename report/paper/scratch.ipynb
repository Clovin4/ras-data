# %%
import streamlit as st
import json
import geopandas as gpd
import pyproj
import plotly.graph_objs as go
import pandas as pd
import folium
from streamlit_folium import st_folium, folium_static

# %%
gages = gpd.read_file(r"C:\Users\christianl\repos\Calibration\data\ref\WF_OneRain_Gauges.shp")
map_df = gages 
map_df.to_crs(pyproj.CRS.from_epsg(6479), inplace=True)
map_df.head()
# Out:
#    FID  FID_1        LAT       LONG SITE_ID                          SITENAME  \
# 0    0      0  30.326278 -93.214694   12003    Belfield Ditch @ Belfield Road
# 1    1      1  30.339806 -93.254139   12004        Indian Bayou @ Coffey Road
# 2    2      4  30.328028 -93.331778   12007       Little River @ Bankens Road
# 3    3      5  30.442900 -93.420520   12008       Buxton Creek @ Douglas Road
# 4    4     14  30.373667 -93.198306   12017  Little Indian Bayou @ Topsy Road
#
#                                                 LINK ALERT_ID ALERT2_ID  \
# 0  https://cppj.onerain.com/site/?site_id=177&sit...      100     12003
# 1  https://cppj.onerain.com/site/?site_id=41&site...      200     12004
# 2  https://cppj.onerain.com/site/?site_id=44&site...      500     12007
# 3  https://cppj.onerain.com/site/?site_id=45&site...      600     12008
# 4  https://cppj.onerain.com/site/?site_id=54&site...     1500     12017
#
#      UPGRADED  STARTDATE      WATERSHED             SUBBASIN  \
# 0  12/19/2018        NaN         Ward 1       BELFIELD DITCH
# 1    8/1/2019  1/28/2010         Ward 1         INDIAN BAYOU
# 2  10/14/2019  3/24/2010  Houston River         LITTLE RIVER
# 3   7/12/2019  3/25/2010  Houston River         BUXTON CREEK
# 4  10/30/2019  6/29/2011         Ward 1  LITTLE INDIAN BAYOU
#
#                                   geometry
# 0  POINT Z (2687381.448 669068.866 25.000)
# 1  POINT Z (2674804.991 674138.452 14.000)
# 2  POINT Z (2650424.310 670420.981 12.000)
# 3  POINT Z (2623219.388 712563.494 54.000)
# 4  POINT Z (2692801.972 686160.901 24.000)

# %%
map_df[['SITE_ID','SITENAME','LAT','LONG']]
# Out:
#    SITE_ID                                     SITENAME        LAT       LONG
# 0    12003               Belfield Ditch @ Belfield Road  30.326278 -93.214694
# 1    12004                   Indian Bayou @ Coffey Road  30.339806 -93.254139
# 2    12007                  Little River @ Bankens Road  30.328028 -93.331778
# 3    12008                  Buxton Creek @ Douglas Road  30.442900 -93.420520
# 4    12017             Little Indian Bayou @ Topsy Road  30.373667 -93.198306
# 5    12019                          L-24 @ Grand Avenue  30.456306 -93.427194
# 6    12020                               L-24 @ Hwy 389  30.475333 -93.458028
# 7    12029           Houston River @ Anthony Ferry Road  30.291306 -93.314528
# 8    12031                    Goldsmith Canal @ Hwy 171  30.354722 -93.200167
# 9    12039                      Bearhead Creek @ Hwy 12  30.334000 -93.628917
# 10   12045                 Houston River @ Edgerly Road  30.314361 -93.501417
# 11   12046                      Buxton Creek @ Route 66  30.356806 -93.453389
# 12   12047                 Cowards Gully @ Edgerly Road  30.381333 -93.459833
# 13   12048                        Buxton Creek @ Hwy 27  30.423250 -93.424500
# 14   12049               L-20 @ Rigmaiden Cemetery Road  30.437250 -93.418333
# 15   12050   Lower West Fork Buxton Creek @ West Street  30.441722 -93.428889
# 16   12051                       Houston River @ Hwy 27  30.290222 -93.355667
# 17   12071                  West Fork @ Dunn Ferry Road  30.344222 -93.282306
# 18   12072           Indian Bayou @ Hickory Branch Road  30.388556 -93.248917
# 19   12073  Little Indian Bayou @ N. Perkins Ferry Road  30.352556 -93.232972
# 20   12074             Belfield Ditch @ Joe Miller Road  30.344778 -93.211639
# 21   12075       Belfield Ditch @ N. Perkins Ferry Road  30.322000 -93.232861
# 22   12076                            BFD-3 @ Park Road  30.315389 -93.219361
# 23   12087                    West Fork @ Holbrook Park  30.348395 -93.294000
# 24   12094              West Fork @ Gahagan Boat Launch  30.299278 -93.250000
# 25   12105               Little Indian Bayou @ Birdnest  30.368276 -93.181000
# 26   12106           Cypress Creek @ Holbrook Park Road  30.394960 -93.368000
# 27   12107            Little River @ Holbrook Park Road  30.393182 -93.382000
# 28   12108           Buxton Creek L93 @ Bud Bennet Road  30.372962 -93.491000
# 29   12113                Bearhead Creek @ Green Island  30.381052 -93.642000

# %%
# rename LONG to LON
map_df.rename(columns={'LONG':'LON'},inplace=True)
map_df.head()
# Out:
#    FID  FID_1        LAT        LON SITE_ID                          SITENAME  \
# 0    0      0  30.326278 -93.214694   12003    Belfield Ditch @ Belfield Road
# 1    1      1  30.339806 -93.254139   12004        Indian Bayou @ Coffey Road
# 2    2      4  30.328028 -93.331778   12007       Little River @ Bankens Road
# 3    3      5  30.442900 -93.420520   12008       Buxton Creek @ Douglas Road
# 4    4     14  30.373667 -93.198306   12017  Little Indian Bayou @ Topsy Road
#
#                                                 LINK ALERT_ID ALERT2_ID  \
# 0  https://cppj.onerain.com/site/?site_id=177&sit...      100     12003
# 1  https://cppj.onerain.com/site/?site_id=41&site...      200     12004
# 2  https://cppj.onerain.com/site/?site_id=44&site...      500     12007
# 3  https://cppj.onerain.com/site/?site_id=45&site...      600     12008
# 4  https://cppj.onerain.com/site/?site_id=54&site...     1500     12017
#
#      UPGRADED  STARTDATE      WATERSHED             SUBBASIN  \
# 0  12/19/2018        NaN         Ward 1       BELFIELD DITCH
# 1    8/1/2019  1/28/2010         Ward 1         INDIAN BAYOU
# 2  10/14/2019  3/24/2010  Houston River         LITTLE RIVER
# 3   7/12/2019  3/25/2010  Houston River         BUXTON CREEK
# 4  10/30/2019  6/29/2011         Ward 1  LITTLE INDIAN BAYOU
#
#                                   geometry
# 0  POINT Z (2687381.448 669068.866 25.000)
# 1  POINT Z (2674804.991 674138.452 14.000)
# 2  POINT Z (2650424.310 670420.981 12.000)
# 3  POINT Z (2623219.388 712563.494 54.000)
# 4  POINT Z (2692801.972 686160.901 24.000)

# %%
# convert lat long to float
map_df['LAT'] = map_df['LAT'].astype(float)

# %%
# set GeoJSON file path
path = r"C:\Users\christianl\repos\Calibration\report\paper\paper.json"
# write GeoJSON to file
map_df.to_file(path, driver = "GeoJSON")
with open(path) as geofile:
   j_file = json.load(geofile)
# index geojson
i=1
for feature in j_file["features"]:
   feature ['id'] = str(i).zfill(2)
   i += 1

# %%
map_df.head()
# Out:
#    FID  FID_1        LAT        LON SITE_ID                          SITENAME  \
# 0    0      0  30.326278 -93.214694   12003    Belfield Ditch @ Belfield Road
# 1    1      1  30.339806 -93.254139   12004        Indian Bayou @ Coffey Road
# 2    2      4  30.328028 -93.331778   12007       Little River @ Bankens Road
# 3    3      5  30.442900 -93.420520   12008       Buxton Creek @ Douglas Road
# 4    4     14  30.373667 -93.198306   12017  Little Indian Bayou @ Topsy Road
#
#                                                 LINK ALERT_ID ALERT2_ID  \
# 0  https://cppj.onerain.com/site/?site_id=177&sit...      100     12003
# 1  https://cppj.onerain.com/site/?site_id=41&site...      200     12004
# 2  https://cppj.onerain.com/site/?site_id=44&site...      500     12007
# 3  https://cppj.onerain.com/site/?site_id=45&site...      600     12008
# 4  https://cppj.onerain.com/site/?site_id=54&site...     1500     12017
#
#      UPGRADED  STARTDATE      WATERSHED             SUBBASIN  \
# 0  12/19/2018        NaN         Ward 1       BELFIELD DITCH
# 1    8/1/2019  1/28/2010         Ward 1         INDIAN BAYOU
# 2  10/14/2019  3/24/2010  Houston River         LITTLE RIVER
# 3   7/12/2019  3/25/2010  Houston River         BUXTON CREEK
# 4  10/30/2019  6/29/2011         Ward 1  LITTLE INDIAN BAYOU
#
#                                   geometry
# 0  POINT Z (2687381.448 669068.866 25.000)
# 1  POINT Z (2674804.991 674138.452 14.000)
# 2  POINT Z (2650424.310 670420.981 12.000)
# 3  POINT Z (2623219.388 712563.494 54.000)
# 4  POINT Z (2692801.972 686160.901 24.000)

# %%
# convert map_df projection to WGS84 for lat and long
map_df = map_df.to_crs(epsg=4326)

# %%
lat = map_df.geometry.y
lon = map_df.geometry.x
map_df['lat'] = lat
map_df['lon'] = lon

# %%
map_df[['lat','lon']]
# Out:
#           lat        lon
# 0   30.326407 -93.214430
# 1   30.339771 -93.254557
# 2   30.328404 -93.331627
# 3   30.442927 -93.420276
# 4   30.373641 -93.198133
# 5   30.456417 -93.427137
# 6   30.475284 -93.458013
# 7   30.291268 -93.314804
# 8   30.354629 -93.200534
# 9   30.333548 -93.629622
# 10  30.314124 -93.501303
# 11  30.356763 -93.453108
# 12  30.381448 -93.459713
# 13  30.423198 -93.424477
# 14  30.437127 -93.418315
# 15  30.441677 -93.428914
# 16  30.290250 -93.355655
# 17  30.341753 -93.285860
# 18  30.388561 -93.249114
# 19  30.352671 -93.232973
# 20  30.344781 -93.211600
# 21  30.322851 -93.232947
# 22  30.315355 -93.219371
# 23  30.348625 -93.293908
# 24  30.299279 -93.249944
# 25  30.368269 -93.181222
# 26  30.394953 -93.367668
# 27  30.393176 -93.382097
# 28  30.372952 -93.491290
# 29  30.381167 -93.641576

# %%
import numpy as np

# %%
df = pd.DataFrame(
    np.random.randn(1000, 2) / [50, 50] + [30.373667, -93.198306],
    columns=['lat', 'lon'])
df.head()
# Out:
#          lat        lon
# 0  30.754856 -90.403280
# 1  30.733561 -90.396141
# 2  30.746028 -90.394730
# 3  30.757932 -90.406356
# 4  30.765268 -90.369974
